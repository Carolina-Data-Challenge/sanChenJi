# %%
import pandas as pd

df = pd.read_csv("./houses_with_names.csv")

banks = df["lei"].value_counts(normalize=True)
banks = banks.reset_index().values.tolist()

# 2d array of LEI's and relative frequencies in order from most frequent to least frequent
banks
# Out:
# [['KB1H1DSPRFMYMCUFXT09', 0.0791163359618695],
#  ['549300SHE1JTCOWBP090', 0.06622275263876032],
#  ['549300DD4R4SYK5RAQ92', 0.04500113395124381],
#  ['JJKC32MCHWDI71265Z06', 0.03131936156686037],
#  ['549300FGXN1K3HLB1R50', 0.02799186529402798],
#  ['RVDPPPGHCGZ40J4VQ731', 0.025686784077093815],
#  ['549300MGPZBLQDIL7538', 0.024069509352309358],
#  ['5493000YNV8IX4VD3X12', 0.02340401009774288],
#  ['549300RWXUAFD1WAE410', 0.019883184432522464],
#  ['B4TYDEB6GKMZO031MB27', 0.017942454762781116],
#  ['254900HA4DQWAE0W3342', 0.01732528785631165],
#  ['C5654JQHZUHN0772B561', 0.016325180037996663],
#  ['5493003GQDUH26DNNH17', 0.015949674872012223],
#  ['L9VVX1KT5TFTKS0MLF66', 0.014343553766019385],
#  ['7H6GLXDRUGQFU57RNE97', 0.012949351417067267],
#  ['549300LYRWPSYPK6S325', 0.012759739897609779],
#  ['MQ445ND48613ADV2WN65', 0.012659357328485226],
#  ['549300DD5QQUHO6PCH70', 0.012417695588000193],
#  ['549300U3721PJGQZYY68', 0.01192321848823851],
# ...
